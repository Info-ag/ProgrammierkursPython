# %% [markdown]
# # Aufgabensammlung für Python Listen

# %%
# Aufgabe 1
# Schreibe eine Funktion die die Anzahl der Elemente in einer beliebigen Liste zählt
l = laenge([2,5,4,1])
print(l)

# %% [markdown]
# # Aufgabensammlung für Python Funktionen

# %%
# Aufgabe 1
# Schreibe eine Funktion die die Anzahl der Elemente in einer beliebigen Liste zählt
l = laenge([2,5,4,1])
print(l)

# %%
# Aufgabe 1
# Rechne die Temperaturen von Fahrenheit in Celsius
# Formel: (°F - 32) x 5/9
temperaturen_fahrenheit = [76.1, 82.5, 58.4, 103.2, 105.2, 96.4, 101.3]

# %%
# Aufgabe 2
# Finde das größte Element der Liste
liste = [5, 28, 18, 0, -5, 182, 23, 93, 2]

# %%
# Aufgabe X
#

# %%
# Knobelaufgabe
# Sortiere die Liste
liste = [5, 28, 18, 0, -5, 182, 23, 93, 2]

# %% [markdown]
# ## Dictionaries
