# %% [markdown]
# ## Die %autosave Zelle unbedingt ausführen

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %% [markdown]
# ## 10. Imports und random

# %% [markdown]
# Zusätzlich zu den normalen Funktionen in Python kann man auch zusätzliche Module *importieren*.
# Man kann ein Modul importieren mit ```import modulname```.
# Diese Module haben eigene Funktionen, die einem viel Arbeit ersparen können. \
# Eines dieser Module ist ```random```. Mit ```random``` kann man auf unterschiedliche Weisen (fast) zufällige Zahlen generieren. Ein Beispiel dafür ist ```random.randint(min, max)```. Mit dieser Funktion kann man einen zufälligen ```int```zwischen ```min``` und ```max``` erzeugen.

# %%
import random

mini = 1
maxi = 10
r = random.randint(mini,maxi)
if int(input("Rate meine Zahl: ")) == r:
    print("Richtig, super geraten!")
else:
    print("Das ist leider nicht meine Zahl")
# Out:
# Rate meine Zahl: 1
# Das ist leider nicht meine Zahl

# %%
## Aufgabe
# Programmiere ein Ratespiel, wobei das Programm eine zufällige Zahl zwischen 1 und 100 wählt und man mehrfach raten kann.
# Das Programm soll einem nach jedem mal raten sagen, ob die geratene Zahl größer, gleich oder kleiner als die gesuchte Zahl ist.

mini = 1
maxi = 100
r = random.randint(mini, maxi)
guess = 0
while (guess != r):
    guess = int(input("Rate meine Zahl: "))
    if guess > r:
        print("zu groß")
    elif guess < r:
        print("zu klein")
print("Richtig, das war meine Zahl!")
# Out:
# Rate meine Zahl: 50
# zu klein
# Rate meine Zahl: 75
# zu klein
# Rate meine Zahl: 88
# zu groß
# Rate meine Zahl: 82
# zu groß
# Rate meine Zahl: 77
# zu klein
# Rate meine Zahl: 80
# zu groß
# Rate meine Zahl: 78
# zu klein
# Rate meine Zahl: 79
# Richtig, das war meine Zahl!

# %% [markdown]
# ## 11. Funktionen

# %% [markdown]
# Funktionen sind ein sehr wichtiges Konzept in der Programmierung, da man mit ihnen einen Codeblock leicht wiederverwendbar machen kann. \
# Die Grundidee ist, dass man einen Codeblock in eine Funktion schreibt, der Funktion einen Namen gibt, und den Codeblock dann ausführen kann, in den man den Namen der Funktion verwendet. Ein Beispiel:
# ```
# def funktionsname():
#     {Codeblock}
# ```
# definiert eine Funktion mit dem Namen ```funktionsname```. Wenn die Zelle mit dem ```def```ausgeführt wird, merkt sich zunächst Python nur den Funktionsnamen und welcher Code darin ist. **Der Code wird bei der Definition noch nicht ausgeführt**. \
# Wenn man die Funktion *aufruft*, wird der in ihr enthaltene Code ausgeführt: \
# ```funktionsname()``` führt den ```{Codeblock}``` aus.

# %%
# In dieser Zelle wird nur die Funktion definiert, nicht ausgeführt.
def sag_hallo():
    print("Hallo!")

# %%
# Jetzt rufen wir die Funktion auf und sie wird ausgeführt.
sag_hallo()
# Out:
# Hallo!

# %%
def vorstellen():
    print("Hallo, ich bin David.")
    print("Ich bin 22 Jahre alt.")
    print("Ich studiere in Karlsruhe Informatik.")
    print("Ich war 3 Jahre im Science Lab")
    print("und ich mag Informatik.")


vorstellen()
vorstellen() # Jetzt kann man die prints nochmal ausführen ohne viel zu schreiben!
# Out:
# Hallo, ich bin David.
# Ich bin 22 Jahre alt.
# Ich studiere in Karlsruhe Informatik.
# Ich war 3 Jahre im Science Lab
# und ich mag Informatik.
# Hallo, ich bin David.
# Ich bin 22 Jahre alt.
# Ich studiere in Karlsruhe Informatik.
# Ich war 3 Jahre im Science Lab
# und ich mag Informatik.

# %% [markdown]
# ## 12. Funktionsparameter

# %% [markdown]
# Man kann Funktionen auch *Parameter* übergeben. Das sind Variablen, die in der Funktion verwendet werden können.

# %%
# Eine Funktion mit dem Parameter "name".
def vorstellen2(name):
    print("Hallo ich bin " + name + ".")


vorstellen2("David")
vorstellen2("Luan")
# Out:
# Hallo ich bin Simon.
# Hallo ich bin Marvin.

# %%
# Eine Funktion kann auch mathematische Berechnungen ausführen
def f(x):
    print(2*x**2 + 3*x - 5)

f(1)
f(3)
# Out:
# 0
# 22

# %% [markdown]
# Man kann einer Funktion auch **mehrere Parameter** übergeben:

# %%
def g(x,y):
    print((x+y)**2)

g(2,3)
g(7,2)
# Out:
# 25
# 81

# %% [markdown]
# ## 13. Returns

# %% [markdown]
# Funktionen können auch Ergebnisse beim Aufrufen zurückgeben.
# Tatsächlich habt ihr schon viele Funktionen mit Rückgaben verwendet: ```range()```, ```len()``` oder ```input()``` sind alles Funktionen, die Daten zurückgeben. \
# Wenn man eine Variable in einer Funktion zurückgeben möchte, schreibt man davor ein ```return```:
# ```
# def funktionsname():
#     ergebnis = ...
#     return ergebnis
# ```
# Beim Aurufen kann man das Ergebnis zum Beispiel in einer Variable speichern:
# ```
# variable = funktionsname()
# ```
# Nun ist das ```ergebnis``` unserer Funktion in ```variable``` gespeichert.

# %%
def f2(x):
    return 2*x**2 + 3*x - 5

y = f2(1)
print(y)

print(f2(3)) # Man kann das Ergebnis auch direkt weiterverwenden, anstatt es in einer Variable zu speichern.
# Out:
# 0
# 22

# %%
## Aufgabe
# Schreibe eine Funktion, die eine Zahl n als Parameter bekommt und dann die Summe aller Zahlen von 1 bis n zurück gibt.
# Führe die Funktion für die Werte n=10, n=200, n=5000 aus und gebe das Ergebnis aus.

def summe_bis_n(n):
    summe = 0
    for i in range(n+1):
        summe += i
    return summe
    
print(summe_bis_n(4))
# Out:
# 10

# %%
## Aufgabe
# Schreibe eine Funktion, die eine Liste von Zahlen bekommt und das kleinste Element zurückgibt.

def minimum(liste):
    minimum = liste[0]
    for element in liste:
        if element < minimum:
            minimum = element
    return minimum

print(minimum([3,7,9,6]))
# Out:
# 3

# %%
def reverse(string):
    rev_string = ""
    for i in range(1,len(string)+1):
        rev_string += string[-i]
    return rev_string

print(reverse("Hallo!"))
print(reverse("RACECAR"))
# Out:
# !ollaH
# RACECAR

# %% [markdown]
# ## Aufgaben

# %%
## Aufgabe 1
# Schreibe eine Funktion, die *eine* beliebige Nullstelle von a*x**2 + b*x + c berechnet.
# Dabei sollen a, b und c Funktionsparameter sein.
# Tipp: Mit math.sqrt(zahl) berechnet man die Wurzel von zahl

import math

def calculate_root(a, b, c): # Mit ein paar Extraschritten ;)
    if a == 0:
        if b == 0:
            raise ValueError("Kein gültiger Term: a=0 und b=0.")
        # Lineare Gleichung: b*x + c = 0  →  x = -c/b
        return -c / b

    diskriminante = b*b - 4*a*c
    if diskriminante < 0:
        raise ValueError("Keine reellen Nullstellen vorhanden (Diskriminante < 0).")

    # Wir nehmen hier die „+“-Lösung: x = (-b + sqrt(D)) / (2a)
    return (-b + math.sqrt(diskriminante)) / (2 * a)

calculate_root(2, 1, -1)
# Out:
# 0.5

# %%
## Aufgabe 2
# Schreibe eine Funktion rotate_string, die einen String s und eine Zahl k bekommt, und den String um k rotiert.
# Bei einer Rotation um 1 wird das letzte Zeichen an den Anfang gesetzt. 
# Bei einer Rotation um k wird dies k mal hintereinander ausgeführt

# Tipp: Ihr könnt, müsst aber nicht, Slices verwenden

# Relativ einfache Version: Nehmt an, dass immer k <= len(s)

# Etwas schwerere Version: k darf größer als len(s) sein (aber kleiner als 10^8). 

# Noch schwerere Version: k darf riesig sein (bis zu 10^18). Beachte, dass du nicht so viele Operationen ausführen kannst,
# du kannst also nicht einfach k mal eins weiter rotieren.


# Lösung einfache Version

def rotate_string(string, k):
    return string[-k:] + string[:-k]

# Lösung etwas schwerere Version

def rotate_string(string, k):
    for i in range(k):
        string = string[-1] + string[:-1]
    return string

# Lösung noch schwerere Version
# Trick ist die große Zahl modulo der Länge des Stringe zu rechnen und erst dann zu rotieren.

def rotate_string(string, k):
    return string[-(k%len(string)):] + string[:-(k%len(string))]
    

rotate_string("abcde", 8618614789093745687856) #"deabc"
# Out:
# 'eabcd'

# %%
## Aufgabe 3 (schwer)
# Vielleicht hast du schonmal was von der Caesar Verschlüsselung gehört. Diese funktioniert wie folgt:
# Du hast einen Nachricht als String und möchtest diese verschlüsseln.
# Du nimmst dir eine Zahl k zwischen 0 und 25 (am besten nicht 0), welche der Schlüssel für deine Verschlüsselung ist.
# Nun schaust du für jeden Buchstaben in deinem String, an welcher Stelle im Alphabet dieser steht.
# Diesen Buchstaben ersetzt du nun mit dem Buchstaben, der k Stellen weiter hinten im Alphabet steht (nach Z fängst du einfach wieder mit A an)
# Die Entschlüsselung soll das wieder Rückgängig machen.
# In unserem Fall besteht der String nur aus Großbuchstaben.

# Programmiere ceasar_enc und ceasar_dec, die eine Nachricht encrypten oder decrypten sollen. (Tipp: Du kannst die rotate_string Funktion verwenden)
# Teste dein Programm

# Beispiel: ceasar_enc("DIEGERMANENGREIFENAN", 2) --> FKGIGTOCPGPITGKHGPCP
# und ceasar_dec("FKGIGTOCPGPITGKHGPCP", 2) --> DIEGERMANENGREIFENAN


def rotate_string(string, k):
    return string[-(k%len(string)):] + string[:-(k%len(string))]


alph = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

def ceasar_enc(message, k):
    rot_alph = rotate_string(alph, k)
    enc_message = ""
    for c in message:
        enc_message += alph[rot_alph.index(c)]
    return enc_message

def ceasar_dec(enc_message, k):
    message = ceasar_enc(enc_message, -k)
    return message

s = "DIEGERMANENGREIFENAN"
enc = ceasar_enc(s,2)
print(enc)
print(ceasar_dec(enc,2))
# Out:
# FKGIGTOCPGPITGKHGPCP
# DIEGERMANENGREIFENAN

# %%
## Aufgabe 4 (schwer)
# Schreibe eine Funktion, die die n-te Fibbonacci-Zahl berechnet.

def fib(n):
    prev_fib = 1
    prev2_fib = 1
    for i in range(3,n+1):
        next_fib = prev_fib + prev2_fib
        prev2_fib = prev_fib
        prev_fib = next_fib
    return prev_fib

print(fib(20))
# Out:
# 6765
