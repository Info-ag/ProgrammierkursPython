# %% [markdown]
# # Über den Programmierkurs
#
# Ihr werdet euch nicht an jedes Detail erinnern, das ist aber normal. Ihr könnt das Script auch benutzen,
# um Dinge nachzuschlagen, aber das Wichtige hier ist die Übung und dass ihr Grundwissen habt.
# Sucht im Internet, wenn ihr nicht wisst, wie etwas funktioniert, das gehört zum Programmieren dazu. \
# Wichtig ist, dass ihr weiter übt, sonst vergesst ihr vieles wieder schnell.
# Es gibt auch noch viel mehr als wir in diesem Kurs behandeln können, wir hoffen ihr macht danach selbstständig weiter.
# Programmieren lernt man durch programmieren, nicht durch Tutorials anschauen.
#
# Die Aufgaben sind das wichtigste, ihr solltet versuchen sie alleine zu machen (oder maximal in zweier Teams, aber schaut, dass dann nicht einer alles alleine macht).
# Wenn ihr etwas nicht verstanden habt, meldet euch direkt.
# Wenn ihr eine Aufgabe nicht lösen könnt, fragt uns, wir helfen euch, versucht es aber unbedingt erst einmal selbst.

# %% [markdown]
# ## 1. Einführung: print

# %%
print("Hallo!")
# Out:
# Hallo!

# %%
### Aufgabe
#Schreibe "Hallo Welt" aus.
print("Hallo Welt!")
# Out:
# Hallo Welt!

# %% [markdown]
# ## 2. Variablen und Strings

# %%
name = "David"
print(name)
# Out:
# David

# %%
plz = "76131"
ort = "Karlsruhe"
print(ort)
ort_mit_plz = "76131 Karlsruhe" # Einfach beides hintereinander abschreiben
print(ort_mit_plz)
# Out:
# Karlsruhe
# 76131 Karlsruhe

# %%
print("Mein Name ist " + name)
# Out:
# Mein Name ist David

# %%
### Aufgabe
# Schreibe in einer Zeile aus wie du heißt und woher du kommst mit den Variablen name und ort
print("Mein Name ist " + name + " und ich komme aus " + ort + " .")
# Out:
# Mein Name ist David und ich komme aus Karlsruhe .

# %% [markdown]
# ## 3. Input und Kommentare

# %%
#name = "David"
# Alles hinter einem '#' ist ein Kommentar und wird nicht ausgeführt
"""
Für mehrzeilige Kommentare kann man auch die dreifachen Anführungszeichen schreiben
Blöd ist nur, dass das dann hier beim Ausführen als String interpretiert wird ;)
"""
# Out:
# '\nFür mehrzeilige Kommentare kann man auch die dreifachen Anführungszeichen schreiben\nBlöd ist nur, dass das dann hier beim Ausführen als String interpretiert wird ;)\n'

# %%
name = input()
# Out:
# David

# %%
print("Wie ist dein Name?")
name = input()
print("Hallo", name) # Das ',' fügt automatisch Leerzeichen ein ('+' nicht!)
# Out:
# Wie ist dein Name?
# David
# Hallo David

# %%
### Aufgabe
# Schreibe "Woher kommst du" und dann schreibe der Variable ort den Input zu
print("Woher kommst du?")
ort = input()
# Out:
# Woher kommst du?
# Karlsruhe

# %%
antwort = input("Wie geht es dir?: ")
if antwort == "gut":
    print("Supi, mir geht es auch gut!")
elif antwort == "schlecht":
    print("Oh das tut mir leid")
else:
    print("Ich kann dich nicht verstehen.")
# Out:
# Wie geht es dir?: gut
# Supi, mir geht es auch gut!

# %% [markdown]
# ## 4. Ganz- und (Fließ-)Kommazahlen

# %%
stunden_programmiert = 3000     # Variable (alles klein geschrieben)
ANTWORT_AUF_ALLES = 42          # Konstante (gewöhnlich alles groß geschrieben)
PI = 3.14159

# %%
# Weil input einen String zurückgibt, muss man das Ergebnis danach zuerst zu einem Integer konvertieren!
alter = int(input("Wie alt bist du?: "))
# Out:
# Wie alt bist du?: 22

# %%
# Mit Zahlen kann man Rechnungen durchführen
computer_alter = 17
alter = int(input("Wie alt bist du? "))

if computer_alter == alter:
    print("Lustig, ich auch")
elif computer_alter > alter:
    print("Dann bin ich ", computer_alter - alter, " Jahre älter als du.")
else:
    print("Dann bist du ", alter - computer_alter, " Jahre älter als ich")
# Out:
# Wie alt bist du? 22
# Dann bist du  5  Jahre älter als ich

# %% [markdown]
# ## 5. Vergleichsoperationen und Bool'sche Operationen

# %%
print("17 >= 17: ", 17 >= 17)
# Out:
# 17 >= 17:  True

# %%
print("17 > 17: ", 17 > 17)
# Out:
# 17 > 17:  False

# %%
print("13 != 17: ", 13 != 17)
print("26 != 'Hallo': ",26 != "Hallo") # Strings in Strings darstellen
print("'Hi' != 'Hi': ", "Hi" != "Hi")
# Out:
# 13 != 17:  True
# 26 != 'Hallo':  True
# 'Hi' != 'Hi':  False

# %%
# Kommentiere hintendran jeweils, ob du glaubst, ob die Variable True oder False ist
a = True
b = False
c = (17 == 24)
d = (5 <= 78)

# %%
e = not c       # Das logische Gegenteil von c
f = a or b      # Wenn eines oder beide Bedingungen erfüllt sind, ist das Ergebnis True
g = a and b     # Nur wenn beide Bedingungen erfüllt sind, ist das Ergebnis True
h = b or (a and not c)

# %%
# Überprüfe nun deine Vermutungen, indem du die Variablen ausschreibst

# %%
if f:
    print("f is True")
if g:
    print("g is True")
else:
    print("g is False")
# Out:
# f is True
# g is False

# %% [markdown]
# ## 6. Mathematische Operationen

# %%
a = 9
b = 12
print(a+b)
print(a-b)
print(a*b)
print(a/b) # Kommazahl
print(12*3+5)
print(12*(3+5))
print(2**4) # 'hoch'
print(3**3)
# Out:
# 21
# -3
# 108
# 0.75
# 41
# 96
# 16
# 27

# %%
c = a/b
print(type(a))  # int
print(type(c))  # double

# Ganz- und Fließkommazahlen werden unterschiedlich gespeichert. 
# In Python kann man trotzdem beide Datentypen problemlos miteinander verrechnen.
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(a//b)     # Floor division (immer einfach abgerundet)
d = a//b
print(type(d))
# Out:
# 0
# <class 'int'>

# %%
# Modulo ("Rest")
print(a%b)
# Out:
# 9

# %%
print(17 % 8)

# Torte 1 -> 8 Stücke
# Torte 2 -> 8 Stücke
# Rest 1 ist das übrig gebliebene Tortenstück, das niemand bekommen hat
# Out:
# 1

# %%
# Überprüfe ob eine Zahl gerade ist
z = int(input("Gib mir eine Zahl: "))
if z % 2 == 0:
    print(z, " ist gerade!")
else:
    print(z, " ist ungerade!")
# Out:
# Gib mir eine Zahl: 42
# 42  ist gerade!

# %% [markdown]
# # Aufgaben
# ## Aufgabe 1: Getränkeverkauf

# %%
# Produkte: Wasser, Bier, Schnaps
# Der Kunde soll eines der Produkte auswählen. Dann musst du ihn ggf nach dem Alter fragen.
# Du kannst ihm immer Wasser, Bier ab 16 Jahren und Schnaps ab 18 Jahren verkaufen.
# Wenn du ihm etwas verkaufst oder nicht verkaufst, mache das mit einem print-Statment deutlich.
print("Was möchtest du kaufen?")
produkt = input()

if produkt == "Wasser":
    print("Danke für dein Einkauf!")
elif produkt == "Bier" or produkt == "Schnaps":
    alter = int(input("Wie alt bist du?"))
    if produkt == "Bier" and alter <= 15:
        print("Du bist leider noch zu jung um Bier zu kaufen.")
    elif produkt == "Schnaps" and alter <= 17:
        print("Du bist leider noch zu jung um Schnaps zu kaufen.")
    else:
        print("Danke für dein Einkauf!")
else:
    print("Ich kenne das Produkt nicht.")
# Out:
# Was möchtest du kaufen?
# Schnaps
# Wie alt bist du?22
# Danke für dein Einkauf!

# %% [markdown]
# ## Aufgabe 2 / Hausaufgabe: FizzBuzz

# %%
# Das Spiel geht so: Man bekommt eine Zahl, wenn diese durch 3 und durch 5 teilbar ist sagt/printet man FizzBuzz, 
# sonst, wenn sie durch 3 teilbar ist Fizz, sonst wenn sie durch 5 teilbar ist Buzz,
# und ansonsten einfach nur die Zahl.
# Programmiere FizzBuzz.
#Lösung
zahl = int(input("Gebe hier die Zahl ein: "))
if zahl % 15 == 0:
    print("Fizzbuzz")
elif zahl % 3 == 0:
    print("Fizz")
elif zahl % 5 == 0:
    print("Buzz")
else:
    print(zahl)
    
# Lösung 2
zahl = int(input("Gebe hier die Zahl ein: "))
output = ""
if zahl % 3 == 0:
    output += "Fizz"
if zahl % 5 == 0:
    output += "Buzz"
if output == "":
    output = zahl
print(output)
# Out:
# Gebe hier die Zahl ein: 15
# Fizzbuzz
# Gebe hier die Zahl ein: 15
# FizzBuzz
